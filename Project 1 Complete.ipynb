# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path
import numpy as np

# Load in file
# Store filepath in a variable
titles_data_csv = Path("Resources/titles.csv")
credits_data_csv = Path("Resources/credits.csv")

# Read titles and credits data file and store into Pandas DataFrames
titles_data_df = pd.read_csv(titles_data_csv)
credits_data_df = pd.read_csv(credits_data_csv)

# %%
credits_data_df
# Out:
#         person_id         id           name      character      role
# 0           59401    ts20945     Joe Besser            Joe     ACTOR
# 1           31460    ts20945     Moe Howard            Moe     ACTOR
# 2           31461    ts20945     Larry Fine          Larry     ACTOR
# 3           21174    tm19248  Buster Keaton    Johnny Gray     ACTOR
# 4           28713    tm19248    Marion Mack  Annabelle Lee     ACTOR
# ...           ...        ...            ...            ...       ...
# 124230    1938589  tm1054116  Sangam Shukla         Madhav     ACTOR
# 124231    1938565  tm1054116   Vijay Thakur  Sanjay Thakur     ACTOR
# 124232     728899  tm1054116  Vanya Wellens        Budhiya     ACTOR
# 124233    1938620  tm1054116   Vishwa Bhanu          Gissu     ACTOR
# 124234    1938620  tm1054116   Vishwa Bhanu            NaN  DIRECTOR
#
# [124235 rows x 5 columns]

# %%
credits_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124235 entries, 0 to 124234
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   person_id  124235 non-null  int64
#  1   id         124235 non-null  object
#  2   name       124235 non-null  object
#  3   character  107948 non-null  object
#  4   role       124235 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ MB

# %%
#count the number of missing values in each column of credits_data_df
credits_data_df.isnull().sum()
# Out:
# person_id        0
# id               0
# name             0
# character    16287
# role             0
# dtype: int64

# %%
#replace null values with 'No Data'
credits_data_df["character"].replace(np.nan, "No Data", inplace = True)
credits_data_df
# Out:
#         person_id         id           name      character      role
# 0           59401    ts20945     Joe Besser            Joe     ACTOR
# 1           31460    ts20945     Moe Howard            Moe     ACTOR
# 2           31461    ts20945     Larry Fine          Larry     ACTOR
# 3           21174    tm19248  Buster Keaton    Johnny Gray     ACTOR
# 4           28713    tm19248    Marion Mack  Annabelle Lee     ACTOR
# ...           ...        ...            ...            ...       ...
# 124230    1938589  tm1054116  Sangam Shukla         Madhav     ACTOR
# 124231    1938565  tm1054116   Vijay Thakur  Sanjay Thakur     ACTOR
# 124232     728899  tm1054116  Vanya Wellens        Budhiya     ACTOR
# 124233    1938620  tm1054116   Vishwa Bhanu          Gissu     ACTOR
# 124234    1938620  tm1054116   Vishwa Bhanu        No Data  DIRECTOR
#
# [124235 rows x 5 columns]

# %%
titles_data_df
# Out:
#              id                            title   type  \
# 0       ts20945                The Three Stooges   SHOW
# 1       tm19248                      The General  MOVIE
# 2       tm82253      The Best Years of Our Lives  MOVIE
# 3       tm83884                  His Girl Friday  MOVIE
# 4       tm56584                In a Lonely Place  MOVIE
# ...         ...                              ...    ...
# 9866   tm510327                     Lily Is Here  MOVIE
# 9867  tm1079144  Jay Nog: Something from Nothing  MOVIE
# 9868   tm847725                          Chasing  MOVIE
# 9869  tm1054116                         Baikunth  MOVIE
# 9870   ts275838                 Waking Up Eighty   SHOW
#
#                                             description  release_year  \
# 0     The Three Stooges were an American vaudeville ...          1934
# 1     During America’s Civil War, Union spies steal ...          1926
# 2     It's the hope that sustains the spirit of ever...          1946
# 3     Hildy, the journalist former wife of newspaper...          1940
# 4     An aspiring actress begins to suspect that her...          1950
# ...                                                 ...           ...
# 9866  Dallas and heroin have one thing in common: Du...          2021
# 9867  Something From Nothing takes you on a stand-up...          2021
# 9868  A cop from Chennai sets out to nab a dreaded d...          2021
# 9869  This story is about prevalent caste problem, e...          2021
# 9870  Kara Stewart, 16, is fed up with just about ev...          2021
#
#      age_certification  runtime  \
# 0                TV-PG       19
# 1                  NaN       78
# 2                  NaN      171
# 3                  NaN       92
# 4                  NaN       94
# ...                ...      ...
# 9866               NaN       93
# 9867               NaN       55
# 9868               NaN      116
# 9869               NaN       72
# 9870               NaN       10
#
#                                                  genres production_countries  \
# 0     ['comedy', 'family', 'animation', 'action', 'f...               ['US']
# 1     ['action', 'drama', 'war', 'western', 'comedy'...               ['US']
# 2                           ['romance', 'war', 'drama']               ['US']
# 3                        ['comedy', 'drama', 'romance']               ['US']
# 4                      ['thriller', 'drama', 'romance']               ['US']
# ...                                                 ...                  ...
# 9866                                          ['drama']               ['US']
# 9867                                         ['comedy']               ['US']
# 9868                                          ['crime']               ['IN']
# 9869                                ['family', 'drama']                   []
# 9870                                          ['drama']                   []
#
#       seasons     imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0        26.0   tt0850645         8.6      1092.0           15.424         7.6
# 1         NaN   tt0017925         8.2     89766.0            8.647         8.0
# 2         NaN   tt0036868         8.1     63026.0            8.435         7.8
# 3         NaN   tt0032599         7.8     57835.0           11.270         7.4
# 4         NaN   tt0042593         7.9     30924.0            8.273         7.6
# ...       ...         ...         ...         ...              ...         ...
# 9866      NaN   tt7672388         5.3        20.0            1.406         NaN
# 9867      NaN  tt15041600         NaN         NaN            0.600         NaN
# 9868      NaN         NaN         NaN         NaN            1.960         NaN
# 9869      NaN  tt14331982         8.4        49.0            0.645         NaN
# 9870      1.0  tt13542552         NaN         NaN              NaN         NaN
#
# [9871 rows x 15 columns]

# %%
titles_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
#  14  tmdb_score            7789 non-null   float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
#count the number of missing values in each column of titles_data_df
titles_data_df.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6487
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8514
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2082
# dtype: int64

# %%
# Drop seasons and age_certification columns because they have a lot of  missing values
titles_data_df.drop(["seasons", "age_certification"], axis = 1, inplace = True)

titles_data_df
# Out:
#              id                            title   type  \
# 0       ts20945                The Three Stooges   SHOW
# 1       tm19248                      The General  MOVIE
# 2       tm82253      The Best Years of Our Lives  MOVIE
# 3       tm83884                  His Girl Friday  MOVIE
# 4       tm56584                In a Lonely Place  MOVIE
# ...         ...                              ...    ...
# 9866   tm510327                     Lily Is Here  MOVIE
# 9867  tm1079144  Jay Nog: Something from Nothing  MOVIE
# 9868   tm847725                          Chasing  MOVIE
# 9869  tm1054116                         Baikunth  MOVIE
# 9870   ts275838                 Waking Up Eighty   SHOW
#
#                                             description  release_year  \
# 0     The Three Stooges were an American vaudeville ...          1934
# 1     During America’s Civil War, Union spies steal ...          1926
# 2     It's the hope that sustains the spirit of ever...          1946
# 3     Hildy, the journalist former wife of newspaper...          1940
# 4     An aspiring actress begins to suspect that her...          1950
# ...                                                 ...           ...
# 9866  Dallas and heroin have one thing in common: Du...          2021
# 9867  Something From Nothing takes you on a stand-up...          2021
# 9868  A cop from Chennai sets out to nab a dreaded d...          2021
# 9869  This story is about prevalent caste problem, e...          2021
# 9870  Kara Stewart, 16, is fed up with just about ev...          2021
#
#       runtime                                             genres  \
# 0          19  ['comedy', 'family', 'animation', 'action', 'f...
# 1          78  ['action', 'drama', 'war', 'western', 'comedy'...
# 2         171                        ['romance', 'war', 'drama']
# 3          92                     ['comedy', 'drama', 'romance']
# 4          94                   ['thriller', 'drama', 'romance']
# ...       ...                                                ...
# 9866       93                                          ['drama']
# 9867       55                                         ['comedy']
# 9868      116                                          ['crime']
# 9869       72                                ['family', 'drama']
# 9870       10                                          ['drama']
#
#      production_countries     imdb_id  imdb_score  imdb_votes  \
# 0                  ['US']   tt0850645         8.6      1092.0
# 1                  ['US']   tt0017925         8.2     89766.0
# 2                  ['US']   tt0036868         8.1     63026.0
# 3                  ['US']   tt0032599         7.8     57835.0
# 4                  ['US']   tt0042593         7.9     30924.0
# ...                   ...         ...         ...         ...
# 9866               ['US']   tt7672388         5.3        20.0
# 9867               ['US']  tt15041600         NaN         NaN
# 9868               ['IN']         NaN         NaN         NaN
# 9869                   []  tt14331982         8.4        49.0
# 9870                   []  tt13542552         NaN         NaN
#
#       tmdb_popularity  tmdb_score
# 0              15.424         7.6
# 1               8.647         8.0
# 2               8.435         7.8
# 3              11.270         7.4
# 4               8.273         7.6
# ...               ...         ...
# 9866            1.406         NaN
# 9867            0.600         NaN
# 9868            1.960         NaN
# 9869            0.645         NaN
# 9870              NaN         NaN
#
# [9871 rows x 13 columns]

# %%
titles_data_df.dtypes
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# runtime                   int64
# genres                   object
# production_countries     object
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object

# %%
# impute values for the rest of the null columns
titles_data_df["description"].fillna("No Data", inplace=True)
titles_data_df["imdb_id"].fillna("No Data", inplace=True)
titles_data_df["imdb_score"].fillna(titles_data_df["imdb_score"].mean(), inplace=True)
titles_data_df["imdb_votes"].fillna(titles_data_df["imdb_votes"].mean(), inplace=True)
titles_data_df["tmdb_popularity"].fillna(titles_data_df["tmdb_popularity"].mean(), inplace=True)
titles_data_df["tmdb_score"].fillna(titles_data_df["tmdb_score"].mean(), inplace=True)

# %%
# Replace empty square brackets [] with "No Data" in the 'production_countries' column

titles_data_df['production_countries'] = titles_data_df['production_countries'].str.replace('\[\]','No Data', regex=True)
titles_data_df
# Out:
#              id                            title   type  \
# 0       ts20945                The Three Stooges   SHOW
# 1       tm19248                      The General  MOVIE
# 2       tm82253      The Best Years of Our Lives  MOVIE
# 3       tm83884                  His Girl Friday  MOVIE
# 4       tm56584                In a Lonely Place  MOVIE
# ...         ...                              ...    ...
# 9866   tm510327                     Lily Is Here  MOVIE
# 9867  tm1079144  Jay Nog: Something from Nothing  MOVIE
# 9868   tm847725                          Chasing  MOVIE
# 9869  tm1054116                         Baikunth  MOVIE
# 9870   ts275838                 Waking Up Eighty   SHOW
#
#                                             description  release_year  \
# 0     The Three Stooges were an American vaudeville ...          1934
# 1     During America’s Civil War, Union spies steal ...          1926
# 2     It's the hope that sustains the spirit of ever...          1946
# 3     Hildy, the journalist former wife of newspaper...          1940
# 4     An aspiring actress begins to suspect that her...          1950
# ...                                                 ...           ...
# 9866  Dallas and heroin have one thing in common: Du...          2021
# 9867  Something From Nothing takes you on a stand-up...          2021
# 9868  A cop from Chennai sets out to nab a dreaded d...          2021
# 9869  This story is about prevalent caste problem, e...          2021
# 9870  Kara Stewart, 16, is fed up with just about ev...          2021
#
#       runtime                                             genres  \
# 0          19  ['comedy', 'family', 'animation', 'action', 'f...
# 1          78  ['action', 'drama', 'war', 'western', 'comedy'...
# 2         171                        ['romance', 'war', 'drama']
# 3          92                     ['comedy', 'drama', 'romance']
# 4          94                   ['thriller', 'drama', 'romance']
# ...       ...                                                ...
# 9866       93                                          ['drama']
# 9867       55                                         ['comedy']
# 9868      116                                          ['crime']
# 9869       72                                ['family', 'drama']
# 9870       10                                          ['drama']
#
#      production_countries     imdb_id  imdb_score    imdb_votes  \
# 0                  ['US']   tt0850645    8.600000   1092.000000
# 1                  ['US']   tt0017925    8.200000  89766.000000
# 2                  ['US']   tt0036868    8.100000  63026.000000
# 3                  ['US']   tt0032599    7.800000  57835.000000
# 4                  ['US']   tt0042593    7.900000  30924.000000
# ...                   ...         ...         ...           ...
# 9866               ['US']   tt7672388    5.300000     20.000000
# 9867               ['US']  tt15041600    5.976395   8533.614253
# 9868               ['IN']     No Data    5.976395   8533.614253
# 9869              No Data  tt14331982    8.400000     49.000000
# 9870              No Data  tt13542552    5.976395   8533.614253
#
#       tmdb_popularity  tmdb_score
# 0           15.424000    7.600000
# 1            8.647000    8.000000
# 2            8.435000    7.800000
# 3           11.270000    7.400000
# 4            8.273000    7.600000
# ...               ...         ...
# 9866         1.406000    5.984247
# 9867         0.600000    5.984247
# 9868         1.960000    5.984247
# 9869         0.645000    5.984247
# 9870         6.910204    5.984247
#
# [9871 rows x 13 columns]

# %%
merged_movie_data= pd.merge(titles_data_df, credits_data_df, on ="id", how="outer")
merged_movie_data
# Out:
#                id              title   type  \
# 0         ts20945  The Three Stooges   SHOW
# 1         ts20945  The Three Stooges   SHOW
# 2         ts20945  The Three Stooges   SHOW
# 3         tm19248        The General  MOVIE
# 4         tm19248        The General  MOVIE
# ...           ...                ...    ...
# 125349  tm1054116           Baikunth  MOVIE
# 125350  tm1054116           Baikunth  MOVIE
# 125351  tm1054116           Baikunth  MOVIE
# 125352  tm1054116           Baikunth  MOVIE
# 125353   ts275838   Waking Up Eighty   SHOW
#
#                                               description  release_year  \
# 0       The Three Stooges were an American vaudeville ...          1934
# 1       The Three Stooges were an American vaudeville ...          1934
# 2       The Three Stooges were an American vaudeville ...          1934
# 3       During America’s Civil War, Union spies steal ...          1926
# 4       During America’s Civil War, Union spies steal ...          1926
# ...                                                   ...           ...
# 125349  This story is about prevalent caste problem, e...          2021
# 125350  This story is about prevalent caste problem, e...          2021
# 125351  This story is about prevalent caste problem, e...          2021
# 125352  This story is about prevalent caste problem, e...          2021
# 125353  Kara Stewart, 16, is fed up with just about ev...          2021
#
#         runtime                                             genres  \
# 0            19  ['comedy', 'family', 'animation', 'action', 'f...
# 1            19  ['comedy', 'family', 'animation', 'action', 'f...
# 2            19  ['comedy', 'family', 'animation', 'action', 'f...
# 3            78  ['action', 'drama', 'war', 'western', 'comedy'...
# 4            78  ['action', 'drama', 'war', 'western', 'comedy'...
# ...         ...                                                ...
# 125349       72                                ['family', 'drama']
# 125350       72                                ['family', 'drama']
# 125351       72                                ['family', 'drama']
# 125352       72                                ['family', 'drama']
# 125353       10                                          ['drama']
#
#        production_countries     imdb_id  imdb_score    imdb_votes  \
# 0                    ['US']   tt0850645    8.600000   1092.000000
# 1                    ['US']   tt0850645    8.600000   1092.000000
# 2                    ['US']   tt0850645    8.600000   1092.000000
# 3                    ['US']   tt0017925    8.200000  89766.000000
# 4                    ['US']   tt0017925    8.200000  89766.000000
# ...                     ...         ...         ...           ...
# 125349              No Data  tt14331982    8.400000     49.000000
# 125350              No Data  tt14331982    8.400000     49.000000
# 125351              No Data  tt14331982    8.400000     49.000000
# 125352              No Data  tt14331982    8.400000     49.000000
# 125353              No Data  tt13542552    5.976395   8533.614253
#
#         tmdb_popularity  tmdb_score  person_id           name      character  \
# 0             15.424000    7.600000    59401.0     Joe Besser            Joe
# 1             15.424000    7.600000    31460.0     Moe Howard            Moe
# 2             15.424000    7.600000    31461.0     Larry Fine          Larry
# 3              8.647000    8.000000    21174.0  Buster Keaton    Johnny Gray
# 4              8.647000    8.000000    28713.0    Marion Mack  Annabelle Lee
# ...                 ...         ...        ...            ...            ...
# 125349         0.645000    5.984247  1938565.0   Vijay Thakur  Sanjay Thakur
# 125350         0.645000    5.984247   728899.0  Vanya Wellens        Budhiya
# 125351         0.645000    5.984247  1938620.0   Vishwa Bhanu          Gissu
# 125352         0.645000    5.984247  1938620.0   Vishwa Bhanu        No Data
# 125353         6.910204    5.984247        NaN            NaN            NaN
#
#             role
# 0          ACTOR
# 1          ACTOR
# 2          ACTOR
# 3          ACTOR
# 4          ACTOR
# ...          ...
# 125349     ACTOR
# 125350     ACTOR
# 125351     ACTOR
# 125352  DIRECTOR
# 125353       NaN
#
# [125354 rows x 17 columns]

# %% [markdown]
# Jannatul

# %%
# What is the distribution of TV shows and movies available on Amazon Prime?

# Filter TV shows and movies from the main dataset
tv_shows = merged_movie_data[merged_movie_data['type'] == 'SHOW']
movies = merged_movie_data[merged_movie_data['type'] == 'MOVIE']

# Get the count of TV shows and movies
tv_show_count = len(tv_shows)
movie_count = len(movies)

# Create labels and sizes for the pie chart
labels = ['TV Shows', 'Movies']
sizes = [tv_show_count, movie_count]

# Create color palette for the pie chart
colors = ["blue", "orange"]

# Plot the pie chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of TV Shows and Movies on Amazon Prime')
plt.axis('equal')

# Save an image of the chart as a PNG file
plt.savefig("PieChart.png")
plt.show()

# %% [markdown]
# Analysis: The pie chart analysis of content distribution on Amazon Prime shows that movies make up the majority, accounting for around 93.2%, while TV shows represent a smaller portion at approximately 6.8%. This indicates that Amazon Prime focuses on providing a wide range of movies, recognizing the popularity of feature-length films among its users. Despite the smaller share, the platform also offers a significant collection of TV shows, acknowledging the demand for serialized storytelling.
# In summary, Amazon Prime prioritizes movies as the main content category but ensures a notable selection of TV shows, aiming to provide a comprehensive streaming experience for a diverse audience.

# %%
# Are there any trends or patterns in the release years of TV shows and movies available on Amazon Prime?

# Filter TV shows and movies separately
tv_shows = merged_movie_data[merged_movie_data['type'] == 'SHOW']
movies = merged_movie_data[merged_movie_data['type'] == 'MOVIE']

# Count the number of titles released in each year for TV shows
tv_show_counts = tv_shows['release_year'].value_counts().sort_index()

# Count the number of titles released in each year for movies
movie_counts = movies['release_year'].value_counts().sort_index()

# Set up the figure and axes
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the line chart for TV shows
ax.plot(tv_show_counts.index, tv_show_counts.values, marker='o', label='TV Shows')

# Plot the line chart for movies
ax.plot(movie_counts.index, movie_counts.values, marker='o', label='Movies')

# Set the labels and title
ax.set_xlabel('Release Year')
ax.set_ylabel('Number of Titles')
ax.set_title('Distribution of Release Years on Amazon Prime')

# Add a legend
ax.legend()

# Save an image of the chart as a PNG file
plt.savefig("LineChart.png")

# Show the plot
plt.show()

# %% [markdown]
# Analysis: The analysis of the line chart reveals the distribution of release years for TV shows and movies available on Amazon Prime. The chart displays the number of titles released each year for both TV shows and movies.
# This analysis highlights the trends and patterns in the release years of content on Amazon Prime. By examining the line chart, we can observe how the number of titles fluctuates over time for TV shows and movies, allowing us to identify notable spikes or declines in content releases.
# The line chart provides a visual representation of the release year distribution, enabling us to understand the overall pattern and popularity of content across different time periods. It also helps us identify specific years or periods that experienced a higher concentration of releases.
# In summary, this analysis offers valuable insights into Amazon Prime's content strategy and viewer preferences based on release years. It emphasizes the platform's commitment to offering a diverse range of movies and TV shows, as evident from the distribution of releases. Understanding the historical context of the content library through this analysis informs content acquisition decisions and showcases Amazon Prime's dedication to providing a comprehensive streaming experience for subscribers.

# %%
# Which directors have the highest total IMDb votes for their movies?
# considering only movies with more than 1000 IMDb votes.

# Filter movies from the merged dataset
movies = merged_movie_data[merged_movie_data['type'] == 'MOVIE']

# Filter movies with IMDb votes greater than 1000
highly_voted_movies = movies[movies['imdb_votes'] > 1000]

# Group movies by director and calculate the total IMDb votes for each director
director_votes = highly_voted_movies.groupby('name')['imdb_votes'].sum()

# Sort the directors based on their total IMDb votes in descending order
top_directors = director_votes.sort_values(ascending=False).head(20)

# Sort the directors in descending order
top_directors = top_directors.sort_values(ascending=True)

# Generate a range of colors using a colormap
colors = plt.cm.viridis(np.linspace(0, 1, len(top_directors)))

# Plot the horizontal bar chart for top directors and their total IMDb votes
plt.figure(figsize=(12, 8))
bars = plt.barh(top_directors.index, top_directors.values.astype(int), color=colors)
plt.xlabel('Total IMDb Votes')
plt.ylabel('Director')
plt.title('Directors with the Most IMDb Votes (>1000)')

# Set the y-axis tick positions and labels
plt.yticks(range(len(top_directors.index)), top_directors.index)

# Assign different colors to each bar
for i, bar in enumerate(bars):
    bar.set_color(colors[i])
    
# Save an image of the chart as a PNG file
plt.savefig("BarChart.png")

# Display the plot
plt.show()

# %% [markdown]
# Analysis: The bar chart shows which directors have received the most IMDb votes for their movies. It focuses on movies with over 1000 IMDb votes. The x-axis represents the total number of IMDb votes, while the y-axis represents the directors. The chart helps us see which directors are the most popular among viewers based on the votes their movies have received.
# This analysis offers valuable information for understanding audience preferences and identifying successful directors on Amazon Prime. It can guide content acquisition decisions by highlighting directors with a strong track record of audience appreciation. By looking at the bar chart, we can easily compare the directors and see who has received the highest number of IMDb votes.
# By evaluating IMDb votes, this analysis enables data-driven decision-making and ensures the selection of high-quality content for subscribers. It enhances the platform's success by providing popular and well-received movies, ultimately contributing to customer satisfaction and engagement on Amazon Prime.

# %% [markdown]
# Suhani

# %%
#Remove list formatting of production Countries
titles_data_df['production_countries'] = titles_data_df['production_countries'].str.strip('[]')
titles_data_df['production_countries'] = titles_data_df['production_countries'].str.replace("'", "")

#Find how many movies were made in each country to get the top 20 most common 
country_mode = titles_data_df['production_countries'].str.split(', ', expand=True).stack().reset_index(level=1, drop=True).rename('country')
top_15 = country_mode.value_counts().head(17)
top_15 = top_15.index.tolist()
top_15.remove('No Data')
top_15.remove('XX')

#filter the dataframe to get only the top 20 countries
filtered_df = titles_data_df[titles_data_df['production_countries'].isin(top_15)]

#How do the average ratings and popularity scores vary across different production countries?

#Bar chart displaying the average ratings for titles produced in different countries
mean_imdb = filtered_df.groupby(['production_countries'])['imdb_score'].agg('mean')
mean_imdb = mean_imdb.sort_values(ascending=False)
Country = mean_imdb.index
plt.bar(Country,mean_imdb.values, color = 'lightsalmon')
plt.xlabel('Production Country')
plt.ylabel('Average IMDB Rating')
plt.ylim(5, 7)
new_labels = ['Japan', ' China', 'South Korea', 'United Kingdom', 'Australia', 'France', 'India', 'Germany','Mexico', 'Spain', 'Hong Kong', 'United States', 'Russia', 'Italy', 'Canada']
plt.xticks(range(len(Country)), new_labels, rotation = 90)
plt.tight_layout()
plt.show()
plt.savefig('Avg.IMDBperCountry.png')

mean_tmdb = filtered_df.groupby(['production_countries'])['tmdb_score'].agg('mean')
mean_tmdb = mean_tmdb.sort_values(ascending=False)
Country_name = mean_tmdb.index
plt.figure()
plt.bar(Country_name,mean_tmdb.values, color = 'burlywood')
plt.xlabel('Production Country')
plt.ylabel('Average TMDB Rating')
plt.ylim(5, 7.5)
new_labels = ['China','Japan', 'South Korea','Mexico','Spain','United Kingdom','Hong Kong', 'Australia','Russia', 'France', 'India', 'Germany','Italy','Canada', 'United States']
plt.xticks(range(len(Country_name)), new_labels, rotation = 90)
plt.tight_layout()
plt.show()
plt.savefig('Avg.TMDBperCountry.png')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 45
#      42 plt.show()
#      43 plt.savefig('Avg.TMDBperCountry.png')
# ---> 45 import scipy.stats as st
#      46 from scipy.stats import linregress
#      48 #Are there any notable differences in ratings and popularity between titles produced in different regions?
#      49
#      50 #Scatter plot showing the relationship between ratings and popularity for titles produced in different countries
#      51 #find the popularity and rating values for this country
#
# ModuleNotFoundError: No module named 'scipy'

# %% [markdown]
# Analysis: The highest rated movies and TV Shows are from China, Japan and South Korea in both IMDB and TMDB ratings which may be due to Asian entertainment gaining massive international success as seen with Anime, K-Dramas, and Chinese cinema. These three countries have been receiving high ratings from their viewers likely due to their unique story-telling style and their captivating stories. Given the increasing popularity of Asian entertainment among a wide audience, it would be a good idea to push forward Asian dramas that align with the users’ genre preferences.

# %%
import scipy.stats as st
from scipy.stats import linregress

#Are there any notable differences in ratings and popularity between titles produced in different regions?

#Scatter plot showing the relationship between ratings and popularity for titles produced in different countries
#find the popularity and rating values for this country
country = ['CA','IN', 'GB', 'US', 'JP']
for place in country:
    country_df = titles_data_df.loc[(titles_data_df['production_countries'] == place)]
    country_pop = country_df[['title', 'production_countries', 'tmdb_popularity', 'tmdb_score' ]]
    
    #assign X and Y values
    x_axis = country_pop['tmdb_popularity']
    y_axis = country_pop['tmdb_score']
    
    #create new figure and plot
    plt.figure()
    plt.scatter(x_axis, y_axis, marker = 'o', color = 'sienna')
    plt.xlabel('TMDB Popularity')
    plt.ylabel('TMDB Score')
    plt.xlim(0,15)
    plt.title(f'{place} Popularity Vs Rating')
    
    #Add linear regression line
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    regress_values = x_axis * slope + intercept
    line_eq = 'y =' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
    
    #plt.scatter(x_axis, y_axis)
    plt.plot(x_axis, regress_values, 'r-')
    plt.annotate(line_eq, (5.8,0.8),fontsize=15, color = 'red')
    plt.show()
    
    #find coorelation
    correlation = st.pearsonr(x_axis, y_axis)
    print(f'The correlation between both factors is {round(correlation[0],2)} with a p-value of {pvalue}')
    plt.savefig(f'Avg.RatingvsPopularity{place}.png')

# %% [markdown]
# The TMDB Popularity and TMDB Score for titles in each of these countries have a correlation value of nearly zero . Although the values looked scattered and messy, we can see a funnel shape in the data, where titles with low popularity can have a wide range of ratings whereas titles wit6h high popularity have around average ratings. This is likely due to the fact that less popular movies have less reviews written about them and since TMDB data is all user based, each persons opinion can greatly affect the rating of the movie whereas, more popular movies have more people writing reviews on them which cause a more average rating outcome. This finding is consistent across all these countries which suggest that popularity likely does not influence title ratings but rather, other factors such as genre, cultural preferences and marketing strategies.
# Markdown cell: It is important to note that IMDB and TMDB ratings are both databases where the rating is dependant on aggregations of user’s reviews on a scale of 1 to 10. Although both databases have a large set of users who provide their feedback, ultimately, the ratings are subjective and depend on personal taste and the data is only representative of a sample of the audience and may not be representative of the general population.

# %% [markdown]
# Margarita

# %%
#Investigate differences in the genre distribution based on ratings on IMD
#Calculate the highest IMDB ratings
high_IMDB_ratings= titles_data_df[titles_data_df['imdb_score']>8]
high_IMDB_ratings

#Calculate the genre frequency of movies and tv shows
genre_counts_df=high_IMDB_ratings['genres'].str.split(',').str[0].value_counts()
genre_counts_df

#calculate the total number of titles
total_titles=len(high_IMDB_ratings)
total_titles

#calculate the percentage of each genre of movies and tv shows
genre_percentage= genre_counts_df/total_titles*100
genre_percentage

#Which genres have the highest distribution among titles with high IMDB ratings?
#Calculate the highest IMDB ratings
high_IMDB_ratings= titles_data_df[titles_data_df['imdb_score']>8]
high_IMDB_ratings

#Calculate the genre frequency of movies and tv shows
genre_counts_df=high_IMDB_ratings['genres'].str.split(',').str[0].value_counts()
genre_counts_df

#calculate the total number of titles
total_titles=len(high_IMDB_ratings)
total_titles

#calculate the percentage of each genre of movies and tv shows
genre_percentage= genre_counts_df/total_titles*100
genre_percentage

#Stacked bar chart illustrating the genre distribution for titles with high IMDB ratings.
#Graphic Data
genre=genre_percentage.index
percentage=genre_percentage.values
#Remove brackets from genre column
genre_clean=[genre.strip("[]''")for genre in genre]
#Create a Bar Chart
plt.bar(genre_clean, percentage, color='b', alpha=0.5,align="center")
plt.xlabel('Genre')
plt.ylabel('Percentage')
plt.title('Genres with highest distributions on IMDB')
plt.xticks(rotation=75)
# Save an image of the chart as a PNG file
plt.savefig("BARChart.png")
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
#  Analysis:
#  After calculating the genres with the highest distribution on IMDB and the percentage of them, we can conclude from the above bar graph that the genres with the highest distribution and preferences of viewers are drama, documentation and comedy. In the same way we can conclude that the difference between these and the less distributed genres (horror, european, fantasy) is too noticeable, therefore amazon could focus on producing more shows with these genres without fear of losing a large amount of audience.

# %%
#Audience preferences on genres based on IMDB ratings
#Create IMDB DATA FRAME
IMDB_Movies_Shows=titles_data_df[['type','genres','imdb_votes']].copy()
IMDB_Movies_Shows['genres']=IMDB_Movies_Shows['genres'].str.split(',').str[0]
IMDB_Movies_Shows['genres'] = IMDB_Movies_Shows['genres'].str.strip("[]").str.strip("'")
IMDB_MOVIES_TVSHOWS=pd.DataFrame(IMDB_Movies_Shows)
IMDB_MOVIES_TVSHOWS

#Top genres on IMDB
IMDB_top_genres = IMDB_MOVIES_TVSHOWS.groupby('genres')['imdb_votes'].mean().sort_values(ascending=False).head(10)
IMDB_top_genres

#Audience preferences on genres based on IMDB VOTES
#Create IMDB DATA FRAME
IMDB_Movies_Shows=titles_data_df[['type','genres','imdb_votes']].copy()
IMDB_Movies_Shows['genres']=IMDB_Movies_Shows['genres'].str.split(',').str[0]
IMDB_Movies_Shows['genres'] = IMDB_Movies_Shows['genres'].str.strip("[]").str.strip("'")
IMDB_MOVIES_TVSHOWS=pd.DataFrame(IMDB_Movies_Shows)
IMDB_MOVIES_TVSHOWS

#Top genres on IMDB
IMDB_top_genres = IMDB_MOVIES_TVSHOWS.groupby('genres')['imdb_votes'].mean().sort_values(ascending=False).head(10)
IMDB_top_genres

#Create Visualization
plt.figure(figsize=(10,8))
IMDB_top_genres.plot(kind='bar',color='b',alpha=0.5,align='center')
plt.title('Top Genres based on IMDB votes')
plt.xlabel('Genres')
plt.ylabel('imdb_votes')
plt.xticks(rotation=75)
# Save an image of the chart as a PNG file
plt.savefig("BarChart2.png")
plt.show

# %% [markdown]
# Analysis:
# After analyzing the genres based on IMDB votes we can conclude the following:
# The three most popular genres, based on IMDB votes are Sci-fi, fantasy and thriller, if we compare this with the results of the genres based on the IMDB score we will notice that there is not such a high distribution in Sci-fi, fantasy and thriller.Therefore the analysis concludes by suggesting the need for a distribution strategy for Sci-fi, fantasy, and thriller genres. This strategy could focus on promoting and distributing titles within these genres to reach a wider audience.

# %% [markdown]
# Arsh

# %%
# Investigate correlations between IMDB score, TMDB score, and popularity.
# Are there any correlations between IMDB score, TMDB score, and popularity?
# Scatter plot matrix visualizing the correlations between IMDB score, TMDB score, and popularity.


#Importing the libraries
import pandas as pd
import matplotlib.pyplot as plt

# Checking the first five rows (to get a look at data & columns required)
titles_data_df.head()

# Setting the variables list for the scatter matrix through the columns in the dataframe
variables = ['imdb_score', 'tmdb_score', 'tmdb_popularity']

# Create visualization using the variables and declare the size of the figures
scatter_matrix = pd.plotting.scatter_matrix (titles_data_df[variables], figsize=(10, 8))


#Loop that iterates over the indices of the variable list and generates a histogram for each variable in the list
for i in range(len(variables)):
    scatter_matrix[i, i].hist(titles_data_df[variables[i]], color='blue')

# Show visualization
plt.show()

# Save visualization
plt.savefig('Q4Vis.PNG')

# %% [markdown]
# Between imdb score and tmdb score: Based on the analysis of the correlation between imdb score and tmdb score, it can be observed that, in general, there is a positive trend between the two variables. As the tmdb score increases, there is a tendency for the imdb score to also increase. However, it is important to note that there are instances where the tmdb score is relatively low, while the imdb score is high. This suggests that there may be other factors influencing the imdb score that are not captured by the tmdb score alone.
#
# Between imdb score and tmdb popularity: Upon analyzing the correlation between imdb score and tmdb popularity, it is evident that there is no discernible strong trend between these two variables. The scatter plot of the data points does not exhibit a clear pattern or correlation. However, it is worth noting that as the imdb score reaches higher extremes, there is a tendency for the tmdb popularity to increase as well. This could suggest that exceptionally high IMDb scores may garner more attention and popularity on the TMDB platform.
#
# Between tmdb score and tmdb popularity: After analyzing the correlation between tmdb score and tmdb popularity, it can be observed that there is no clear trend or strong correlation between these two variables. The scatter plot of the data points does not display a distinct pattern or relationship. However, it is noteworthy that there are numerous instances where tmdb popularity reaches high values when tmdb score falls within the range of 5 to 10.
